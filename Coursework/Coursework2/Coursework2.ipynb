# %% [markdown]
# <a href="https://colab.research.google.com/github/JGrant3101/ME4MachineLearning/blob/main/Coursework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Will start by importing all the libraries which might need to be used.

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn import datasets
from sklearn import model_selection
from sklearn import naive_bayes
from sklearn import linear_model
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import KFold
import pandas
import plotly.graph_objects as go
import sys
import tensorflow
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import *

# %% [markdown]
# Firstly going to build the neural network for dataset1

# %%
# Start by importing the dataset
dataset1 = pandas.read_csv('/content/dataset1.csv')

# Write each column of the file to an array to make it easier to work with
ArmLength1 = np.array(dataset1['Arm length (m)'][:])
BallWeight1 = np.array(dataset1['Ball weight (kg)'][:])
BallRadius1 = np.array(dataset1['Ball radius (mm)'][:])
AirTemp1 = np.array(dataset1['Air temperature (deg C)'][:])
SpringConst1 = np.array(dataset1['Spring constant (N per m)'][:])
DeviceWeight1 = np.array(dataset1['Device weight (kg)'][:])
TargetHit1 = np.array(dataset1['Target hit'][:])
# Converting our currently 1D y values to 2D to match our model
TargetHit1_binary = to_categorical(TargetHit1)

# Going to scale each all of the data so want to find the mean and standard deviation
ArmLength1Mean = np.mean(ArmLength1)
ArmLength1std = np.std(ArmLength1)
BallWeight1Mean = np.mean(BallWeight1)
BallWeight1std = np.std(BallWeight1)
BallRadius1Mean = np.mean(BallRadius1)
BallRadius1std = np.std(BallRadius1)
AirTemp1Mean = np.mean(AirTemp1)
AirTemp1std = np.std(AirTemp1)
SpringConst1Mean = np.mean(SpringConst1)
SpringConst1std = np.std(SpringConst1)
DeviceWeight1Mean = np.mean(DeviceWeight1)
DeviceWeight1std = np.std(DeviceWeight1)

# Finally creating the scaled arrays using these mean and std values
ArmLength1Scaled = (ArmLength1 - ArmLength1Mean)/ArmLength1std
BallWeight1Scaled = (BallWeight1 - BallWeight1Mean)/BallWeight1std
BallRadius1Scaled = (BallRadius1 - BallRadius1Mean)/BallRadius1std
AirTemp1Scaled = (AirTemp1 - AirTemp1Mean)/AirTemp1std
SpringConst1Scaled = (SpringConst1 - SpringConst1Mean)/SpringConst1std
DeviceWeight1Scaled = (DeviceWeight1 - DeviceWeight1Mean)/DeviceWeight1std

# Finally forming these into one array to be parsed into the fit function
Inputs1 = np.zeros((2000, 6))
Inputs1[:,0] = ArmLength1Scaled
Inputs1[:,1] = BallWeight1Scaled
Inputs1[:,2] = BallRadius1Scaled
Inputs1[:,3] = AirTemp1Scaled
Inputs1[:,4] = SpringConst1Scaled
Inputs1[:,5] = DeviceWeight1Scaled

# %% [markdown]
# Above we have imported and processed our input data to be used to train the network

# %% [markdown]
# Now will do the actual construction of the network

# %%
# Initialising our neural network
model1 = Sequential()

# Adding layers, these layers are two layers of 4 nodes using the ReLU function and 1 with 2 nodes using the softmax function
model1.add(Dense(units = 4, activation = 'relu', input_dim = 6))
#model1.add(Dense(units = 2, activation = 'selu'))
model1.add(Dense(units = 2, activation = 'softmax'))

# Compiling the model
model1.compile(loss = 'categorical_crossentropy', optimizer = 'Adam')
# Fitting the model
model1.fit(Inputs1, TargetHit1_binary, epochs = 400, batch_size = 40)
# Out:
# Epoch 1/400
# 50/50 [==============================] - 1s 3ms/step - loss: 1.0236
# Epoch 2/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8748
# Epoch 3/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7721
# Epoch 4/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7005
# Epoch 5/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6485
# Epoch 6/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6086
# Epoch 7/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5761
# Epoch 8/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5475
# Epoch 9/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5224
# Epoch 10/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4989
# Epoch 11/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4765
# Epoch 12/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4556
# Epoch 13/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4357
# Epoch 14/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4169
# Epoch 15/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3995
# Epoch 16/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3836
# Epoch 17/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3687
# Epoch 18/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3551
# Epoch 19/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3428
# Epoch 20/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3321
# Epoch 21/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3228
# Epoch 22/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3144
# Epoch 23/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3069
# Epoch 24/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3000
# Epoch 25/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2939
# Epoch 26/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2885
# Epoch 27/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2836
# Epoch 28/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2790
# Epoch 29/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2752
# Epoch 30/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2715
# Epoch 31/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2680
# Epoch 32/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2650
# Epoch 33/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2622
# Epoch 34/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2596
# Epoch 35/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2570
# Epoch 36/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2547
# Epoch 37/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2525
# Epoch 38/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2506
# Epoch 39/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2488
# Epoch 40/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2469
# Epoch 41/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2453
# Epoch 42/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2439
# Epoch 43/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2425
# Epoch 44/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2410
# Epoch 45/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2396
# Epoch 46/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2385
# Epoch 47/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2376
# Epoch 48/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2360
# Epoch 49/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2348
# Epoch 50/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2338
# Epoch 51/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2324
# Epoch 52/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2312
# Epoch 53/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2305
# Epoch 54/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2290
# Epoch 55/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2280
# Epoch 56/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2267
# Epoch 57/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2257
# Epoch 58/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2244
# Epoch 59/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2234
# Epoch 60/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2224
# Epoch 61/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2210
# Epoch 62/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2200
# Epoch 63/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2189
# Epoch 64/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2175
# Epoch 65/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2166
# Epoch 66/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2153
# Epoch 67/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2143
# Epoch 68/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2132
# Epoch 69/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2122
# Epoch 70/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2112
# Epoch 71/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2103
# Epoch 72/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2094
# Epoch 73/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2087
# Epoch 74/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2079
# Epoch 75/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2066
# Epoch 76/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2056
# Epoch 77/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2052
# Epoch 78/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2042
# Epoch 79/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2037
# Epoch 80/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2032
# Epoch 81/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2023
# Epoch 82/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2016
# Epoch 83/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2012
# Epoch 84/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2005
# Epoch 85/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2001
# Epoch 86/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1996
# Epoch 87/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1992
# Epoch 88/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1985
# Epoch 89/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1984
# Epoch 90/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1980
# Epoch 91/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1976
# Epoch 92/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1969
# Epoch 93/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1968
# Epoch 94/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1964
# Epoch 95/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1960
# Epoch 96/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1958
# Epoch 97/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1956
# Epoch 98/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1957
# Epoch 99/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1950
# Epoch 100/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1946
# Epoch 101/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1944
# Epoch 102/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1943
# Epoch 103/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1939
# Epoch 104/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1938
# Epoch 105/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1933
# Epoch 106/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1932
# Epoch 107/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1931
# Epoch 108/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1928
# Epoch 109/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1927
# Epoch 110/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1925
# Epoch 111/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1924
# Epoch 112/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1924
# Epoch 113/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1919
# Epoch 114/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1917
# Epoch 115/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1915
# Epoch 116/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1915
# Epoch 117/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1915
# Epoch 118/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1911
# Epoch 119/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1910
# Epoch 120/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1910
# Epoch 121/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1907
# Epoch 122/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1907
# Epoch 123/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1904
# Epoch 124/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1903
# Epoch 125/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1904
# Epoch 126/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1900
# Epoch 127/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1901
# Epoch 128/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1905
# Epoch 129/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1900
# Epoch 130/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1898
# Epoch 131/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1896
# Epoch 132/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1893
# Epoch 133/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1892
# Epoch 134/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1892
# Epoch 135/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1890
# Epoch 136/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1888
# Epoch 137/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1888
# Epoch 138/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1886
# Epoch 139/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1886
# Epoch 140/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1884
# Epoch 141/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1880
# Epoch 142/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1882
# Epoch 143/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1879
# Epoch 144/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1880
# Epoch 145/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1875
# Epoch 146/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1874
# Epoch 147/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1874
# Epoch 148/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1872
# Epoch 149/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1871
# Epoch 150/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1869
# Epoch 151/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1868
# Epoch 152/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1870
# Epoch 153/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1867
# Epoch 154/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1863
# Epoch 155/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1864
# Epoch 156/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1862
# Epoch 157/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1861
# Epoch 158/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1860
# Epoch 159/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1859
# Epoch 160/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1860
# Epoch 161/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1857
# Epoch 162/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1857
# Epoch 163/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1859
# Epoch 164/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1855
# Epoch 165/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1851
# Epoch 166/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1851
# Epoch 167/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1851
# Epoch 168/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1851
# Epoch 169/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1851
# Epoch 170/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1848
# Epoch 171/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1851
# Epoch 172/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1847
# Epoch 173/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1845
# Epoch 174/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1848
# Epoch 175/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1845
# Epoch 176/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1844
# Epoch 177/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1844
# Epoch 178/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1843
# Epoch 179/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1844
# Epoch 180/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1842
# Epoch 181/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1842
# Epoch 182/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1844
# Epoch 183/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1839
# Epoch 184/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1839
# Epoch 185/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1840
# Epoch 186/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1840
# Epoch 187/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1837
# Epoch 188/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1836
# Epoch 189/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1840
# Epoch 190/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1836
# Epoch 191/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1834
# Epoch 192/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1836
# Epoch 193/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1834
# Epoch 194/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1835
# Epoch 195/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1829
# Epoch 196/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1832
# Epoch 197/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1828
# Epoch 198/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1830
# Epoch 199/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1829
# Epoch 200/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1829
# Epoch 201/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1829
# Epoch 202/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1827
# Epoch 203/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1827
# Epoch 204/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1825
# Epoch 205/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1827
# Epoch 206/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1825
# Epoch 207/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1827
# Epoch 208/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1824
# Epoch 209/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1824
# Epoch 210/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1826
# Epoch 211/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1822
# Epoch 212/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1824
# Epoch 213/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1824
# Epoch 214/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1823
# Epoch 215/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1819
# Epoch 216/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1822
# Epoch 217/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1820
# Epoch 218/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1821
# Epoch 219/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1821
# Epoch 220/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1824
# Epoch 221/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1821
# Epoch 222/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1818
# Epoch 223/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1819
# Epoch 224/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1817
# Epoch 225/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1818
# Epoch 226/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1818
# Epoch 227/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1816
# Epoch 228/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1815
# Epoch 229/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1818
# Epoch 230/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1816
# Epoch 231/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1814
# Epoch 232/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1813
# Epoch 233/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1813
# Epoch 234/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1812
# Epoch 235/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1813
# Epoch 236/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1814
# Epoch 237/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1816
# Epoch 238/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1813
# Epoch 239/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1812
# Epoch 240/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1815
# Epoch 241/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1815
# Epoch 242/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1811
# Epoch 243/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1808
# Epoch 244/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1809
# Epoch 245/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1808
# Epoch 246/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1807
# Epoch 247/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1810
# Epoch 248/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1809
# Epoch 249/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1806
# Epoch 250/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1807
# Epoch 251/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1804
# Epoch 252/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1805
# Epoch 253/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1806
# Epoch 254/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1804
# Epoch 255/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1803
# Epoch 256/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1805
# Epoch 257/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1806
# Epoch 258/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1804
# Epoch 259/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1805
# Epoch 260/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1805
# Epoch 261/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1801
# Epoch 262/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1801
# Epoch 263/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1802
# Epoch 264/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1802
# Epoch 265/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1801
# Epoch 266/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1804
# Epoch 267/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1802
# Epoch 268/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1800
# Epoch 269/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1800
# Epoch 270/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1799
# Epoch 271/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1801
# Epoch 272/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1797
# Epoch 273/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1800
# Epoch 274/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1799
# Epoch 275/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1799
# Epoch 276/400
# 50/50 [==============================] - 0s 8ms/step - loss: 0.1796
# Epoch 277/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1796
# Epoch 278/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1799
# Epoch 279/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1795
# Epoch 280/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1797
# Epoch 281/400
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1796
# Epoch 282/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1796
# Epoch 283/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1800
# Epoch 284/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1795
# Epoch 285/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1793
# Epoch 286/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1795
# Epoch 287/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1794
# Epoch 288/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1797
# Epoch 289/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1793
# Epoch 290/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1793
# Epoch 291/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1793
# Epoch 292/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1795
# Epoch 293/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1793
# Epoch 294/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1792
# Epoch 295/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1791
# Epoch 296/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1792
# Epoch 297/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1791
# Epoch 298/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1793
# Epoch 299/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1791
# Epoch 300/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1789
# Epoch 301/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1792
# Epoch 302/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1792
# Epoch 303/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1789
# Epoch 304/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1790
# Epoch 305/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1794
# Epoch 306/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1789
# Epoch 307/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1793
# Epoch 308/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1791
# Epoch 309/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1789
# Epoch 310/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1787
# Epoch 311/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1789
# Epoch 312/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1789
# Epoch 313/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1788
# Epoch 314/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1787
# Epoch 315/400
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1788
# Epoch 316/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1786
# Epoch 317/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1788
# Epoch 318/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1787
# Epoch 319/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1787
# Epoch 320/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1784
# Epoch 321/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1787
# Epoch 322/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1785
# Epoch 323/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1785
# Epoch 324/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1785
# Epoch 325/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1787
# Epoch 326/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1785
# Epoch 327/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1785
# Epoch 328/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1784
# Epoch 329/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1786
# Epoch 330/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1785
# Epoch 331/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1784
# Epoch 332/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 333/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1782
# Epoch 334/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 335/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1786
# Epoch 336/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 337/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 338/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1781
# Epoch 339/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 340/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 341/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 342/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1782
# Epoch 343/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1782
# Epoch 344/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 345/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 346/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1782
# Epoch 347/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 348/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1779
# Epoch 349/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1783
# Epoch 350/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1779
# Epoch 351/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1778
# Epoch 352/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 353/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 354/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 355/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1779
# Epoch 356/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1778
# Epoch 357/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1779
# Epoch 358/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1776
# Epoch 359/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1778
# Epoch 360/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1779
# Epoch 361/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1781
# Epoch 362/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1778
# Epoch 363/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 364/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1776
# Epoch 365/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1778
# Epoch 366/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 367/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 368/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1778
# Epoch 369/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 370/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 371/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 372/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 373/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 374/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 375/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1779
# Epoch 376/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 377/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 378/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 379/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1776
# Epoch 380/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 381/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 382/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 383/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 384/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 385/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 386/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 387/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 388/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 389/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1772
# Epoch 390/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1776
# Epoch 391/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1771
# Epoch 392/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1773
# Epoch 393/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 394/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 395/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 396/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1772
# Epoch 397/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1772
# Epoch 398/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1773
# Epoch 399/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1775
# Epoch 400/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1774

# %% [markdown]
# Above is the construction of the neural network, as we have 2000 points I think we can do a 5 split K fold cross validation and get good results so going to run that below in order to see what results the model gives and be able to work on improving it. This method is important to ensure that minimal overfitting is ocurring.

# %%
# Setting up a k fold cross validation
kf1 = KFold(n_splits = 5, shuffle = True)

# Defining empty arrays to add our fraction values to so an average can be calculated at the end
testfractions1 = 0
trainfractions1 = 0


for train_index, test_index in kf1.split(Inputs1):
  TrainingInputs = Inputs1[train_index]
  TrainingTargetHit = TargetHit1_binary[train_index]
  TestInputs = Inputs1[test_index]
  TestTargetHit = TargetHit1_binary[test_index]
  # Initialising our neural network
  model1kfold = Sequential()

  # Adding layers, these layers are two layers of 4 nodes using the ReLU function and 1 with 2 nodes using the softmax function
  model1kfold.add(Dense(units = 4, activation = 'relu', input_dim = 6))
  model1kfold.add(Dense(units = 2, activation = 'softmax'))

  # Compiling the model
  model1kfold.compile(loss = 'categorical_crossentropy', optimizer = 'Adam')

  # Use X_train, y_train to train the SVM
  model1kfold.fit(TrainingInputs, TrainingTargetHit, epochs = 400, batch_size = 40)
  # Use svm.predict() to predict the output for the test data set
  testresults = model1kfold.predict(TestInputs)
  # loop through to compare the test data output to what it should be and obtain the fraction of correct classifications
  count = 0
  for i in range(len(TestTargetHit[:,0])):
    if (testresults[i, 0] > testresults[i, 1] and TestTargetHit[i, 0] > TestTargetHit[i, 1]) or (testresults[i, 0] < testresults[i, 1] and TestTargetHit[i, 0] < TestTargetHit[i, 1]):
      count = count+1
  testfractions1 = testfractions1 + (count / len(TestTargetHit[:,0]))
  # Do the same prediction and assessment performance with the training data
  count = 0
  trainresults = model1kfold.predict(TrainingInputs)
  for i in range(len(TrainingTargetHit[:,0])):
    if (trainresults[i, 0] > trainresults[i, 1] and TrainingTargetHit[i, 0] > TrainingTargetHit[i, 1]) or (trainresults[i, 0] < trainresults[i, 1] and TrainingTargetHit[i, 0] < TrainingTargetHit[i, 1]):
      count = count+1
  trainfractions1 = trainfractions1 + (count / len(TrainingTargetHit[:,0]))

# Dividing the sum of 5 fraction values to get the average
testfraction1 = testfractions1/5
trainfraction1 = trainfractions1/5

# Printing the final accuracy values
print(testfraction1)
print(trainfraction1)

# %% [markdown]
# Now model has been tested and proven out can export and run through the check script provided to check everything works and also get an idea of how accurate it is.

# %%
# Exporting the model
model1.save('jg619-1.h5')

# Saving the scaling parameters for temperature and strength
scArray = np.array([[ArmLength1Mean, BallWeight1Mean, BallRadius1Mean, AirTemp1Mean, SpringConst1Mean, DeviceWeight1Mean], [ArmLength1std, BallWeight1std, BallRadius1std, AirTemp1std, SpringConst1std, DeviceWeight1std]])
np.savetxt('jg619-1.txt', scArray)

# Downloading the files
from google.colab import files
files.download('jg619-1.h5')
files.download('jg619-1.txt')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Above is all the code required for dataset 1, will copy the code blocks and replicate them below for dataset 2

# %%
# Start by importing the dataset
dataset2 = pandas.read_csv('/content/dataset2.csv')

# Write each column of the file to an array to make it easier to work with
ArmLength2 = np.array(dataset2['Arm length (m)'][:])
BallWeight2 = np.array(dataset2['Ball weight (kg)'][:])
BallRadius2 = np.array(dataset2['Ball radius (mm)'][:])
AirTemp2 = np.array(dataset2['Air temperature (deg C)'][:])
SpringConst2 = np.array(dataset2['Spring constant (N per m)'][:])
DeviceWeight2 = np.array(dataset2['Device weight (kg)'][:])
TargetHit2 = np.array(dataset2['Target hit'][:])
# Converting our currently 1D y values to 2D to match our model
TargetHit2_binary = to_categorical(TargetHit2)

# Going to scale each all of the data so want to find the mean and standard deviation
ArmLength2Mean = np.mean(ArmLength2)
ArmLength2std = np.std(ArmLength2)
BallWeight2Mean = np.mean(BallWeight2)
BallWeight2std = np.std(BallWeight2)
BallRadius2Mean = np.mean(BallRadius2)
BallRadius2std = np.std(BallRadius2)
AirTemp2Mean = np.mean(AirTemp2)
AirTemp2std = np.std(AirTemp2)
SpringConst2Mean = np.mean(SpringConst2)
SpringConst2std = np.std(SpringConst2)
DeviceWeight2Mean = np.mean(DeviceWeight2)
DeviceWeight2std = np.std(DeviceWeight2)

# Finally creating the scaled arrays using these mean and std values
ArmLength2Scaled = (ArmLength2 - ArmLength2Mean)/ArmLength2std
BallWeight2Scaled = (BallWeight2 - BallWeight2Mean)/BallWeight2std
BallRadius2Scaled = (BallRadius2 - BallRadius2Mean)/BallRadius2std
AirTemp2Scaled = (AirTemp2 - AirTemp2Mean)/AirTemp2std
SpringConst2Scaled = (SpringConst2 - SpringConst2Mean)/SpringConst2std
DeviceWeight2Scaled = (DeviceWeight2 - DeviceWeight2Mean)/DeviceWeight2std

# Finally forming these into one array to be parsed into the fit function
Inputs2 = np.zeros((4000, 6))
Inputs2[:,0] = ArmLength2Scaled
Inputs2[:,1] = BallWeight2Scaled
Inputs2[:,2] = BallRadius2Scaled
Inputs2[:,3] = AirTemp2Scaled
Inputs2[:,4] = SpringConst2Scaled
Inputs2[:,5] = DeviceWeight2Scaled

# %% [markdown]
# As this dataset is more computationally expensive to solve but still want to test some unseen data while developing will write some code to split the dataset 80/20 randomly

# %%
# Initialising our neural network
model2 = Sequential()

# Adding layers, these layers are two layers of 4 nodes using the ReLU function and 1 with 2 nodes using the softmax function
model2.add(Dense(units = 6, activation = 'LeakyReLU', input_dim = 6))
model2.add(Dense(units = 4, activation = 'selu'))
model2.add(Dense(units = 6, activation = 'tanh'))
#model2.add(Dense(units = 4, activation = 'selu'))
#model2.add(Dense(units = 6, activation = 'tanh'))
model2.add(Dense(units = 4, activation = 'LeakyReLU'))
model2.add(Dense(units = 2, activation = 'softmax'))

# Compiling the model
model2.compile(loss = 'categorical_crossentropy', optimizer = 'Adam')
# Fitting the model
model2.fit(Inputs2, TargetHit2_binary, epochs = 300, batch_size = 20)
# Out:
# Epoch 1/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.7234
# Epoch 2/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6969
# Epoch 3/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6937
# Epoch 4/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6923
# Epoch 5/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6901
# Epoch 6/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6870
# Epoch 7/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6833
# Epoch 8/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6784
# Epoch 9/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6727
# Epoch 10/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6657
# Epoch 11/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6597
# Epoch 12/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6549
# Epoch 13/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6512
# Epoch 14/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6474
# Epoch 15/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6452
# Epoch 16/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6425
# Epoch 17/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6405
# Epoch 18/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6401
# Epoch 19/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6390
# Epoch 20/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6378
# Epoch 21/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6374
# Epoch 22/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6366
# Epoch 23/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6364
# Epoch 24/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6348
# Epoch 25/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6347
# Epoch 26/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6352
# Epoch 27/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6348
# Epoch 28/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6337
# Epoch 29/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6333
# Epoch 30/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6336
# Epoch 31/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6331
# Epoch 32/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6327
# Epoch 33/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6332
# Epoch 34/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6322
# Epoch 35/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6318
# Epoch 36/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6325
# Epoch 37/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6322
# Epoch 38/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6318
# Epoch 39/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6315
# Epoch 40/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6308
# Epoch 41/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6307
# Epoch 42/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6314
# Epoch 43/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6309
# Epoch 44/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6306
# Epoch 45/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6298
# Epoch 46/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6294
# Epoch 47/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6292
# Epoch 48/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6289
# Epoch 49/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6289
# Epoch 50/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6285
# Epoch 51/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6276
# Epoch 52/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6278
# Epoch 53/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6270
# Epoch 54/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6272
# Epoch 55/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6263
# Epoch 56/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6265
# Epoch 57/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6252
# Epoch 58/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6248
# Epoch 59/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6242
# Epoch 60/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6221
# Epoch 61/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6242
# Epoch 62/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6219
# Epoch 63/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6213
# Epoch 64/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6209
# Epoch 65/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6197
# Epoch 66/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6189
# Epoch 67/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6184
# Epoch 68/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6179
# Epoch 69/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6168
# Epoch 70/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6158
# Epoch 71/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6150
# Epoch 72/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6139
# Epoch 73/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6127
# Epoch 74/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6116
# Epoch 75/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6103
# Epoch 76/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6095
# Epoch 77/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6092
# Epoch 78/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6067
# Epoch 79/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6065
# Epoch 80/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6059
# Epoch 81/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6047
# Epoch 82/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6028
# Epoch 83/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6017
# Epoch 84/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6013
# Epoch 85/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5992
# Epoch 86/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5979
# Epoch 87/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5958
# Epoch 88/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5950
# Epoch 89/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5934
# Epoch 90/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5923
# Epoch 91/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5913
# Epoch 92/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5884
# Epoch 93/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5883
# Epoch 94/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5857
# Epoch 95/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5840
# Epoch 96/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5818
# Epoch 97/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5803
# Epoch 98/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5787
# Epoch 99/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5778
# Epoch 100/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5759
# Epoch 101/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5741
# Epoch 102/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5731
# Epoch 103/300
# 200/200 [==============================] - 1s 2ms/step - loss: 0.5720
# Epoch 104/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5701
# Epoch 105/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5690
# Epoch 106/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5676
# Epoch 107/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5671
# Epoch 108/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5660
# Epoch 109/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5648
# Epoch 110/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5630
# Epoch 111/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5631
# Epoch 112/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5616
# Epoch 113/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5610
# Epoch 114/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5604
# Epoch 115/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5584
# Epoch 116/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5579
# Epoch 117/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5571
# Epoch 118/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5564
# Epoch 119/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5559
# Epoch 120/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5549
# Epoch 121/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5558
# Epoch 122/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5538
# Epoch 123/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5532
# Epoch 124/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5533
# Epoch 125/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5524
# Epoch 126/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5500
# Epoch 127/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5508
# Epoch 128/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5507
# Epoch 129/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5494
# Epoch 130/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5495
# Epoch 131/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5496
# Epoch 132/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5489
# Epoch 133/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5475
# Epoch 134/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5475
# Epoch 135/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5479
# Epoch 136/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5462
# Epoch 137/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5460
# Epoch 138/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5460
# Epoch 139/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5449
# Epoch 140/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5454
# Epoch 141/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5457
# Epoch 142/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5439
# Epoch 143/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5425
# Epoch 144/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5437
# Epoch 145/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5428
# Epoch 146/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5428
# Epoch 147/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5424
# Epoch 148/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5420
# Epoch 149/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5413
# Epoch 150/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5428
# Epoch 151/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5411
# Epoch 152/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5397
# Epoch 153/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5397
# Epoch 154/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5402
# Epoch 155/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5403
# Epoch 156/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5389
# Epoch 157/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5381
# Epoch 158/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5379
# Epoch 159/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5393
# Epoch 160/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5393
# Epoch 161/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5385
# Epoch 162/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5374
# Epoch 163/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5373
# Epoch 164/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5359
# Epoch 165/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5364
# Epoch 166/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5361
# Epoch 167/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5349
# Epoch 168/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5352
# Epoch 169/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5362
# Epoch 170/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5341
# Epoch 171/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5346
# Epoch 172/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5348
# Epoch 173/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5349
# Epoch 174/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5335
# Epoch 175/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5351
# Epoch 176/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5317
# Epoch 177/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5323
# Epoch 178/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5323
# Epoch 179/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5315
# Epoch 180/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5316
# Epoch 181/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5311
# Epoch 182/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5313
# Epoch 183/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5307
# Epoch 184/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5300
# Epoch 185/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5304
# Epoch 186/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5303
# Epoch 187/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5306
# Epoch 188/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5304
# Epoch 189/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5296
# Epoch 190/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5284
# Epoch 191/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5289
# Epoch 192/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5279
# Epoch 193/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5276
# Epoch 194/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5288
# Epoch 195/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5274
# Epoch 196/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5275
# Epoch 197/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5271
# Epoch 198/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5269
# Epoch 199/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5282
# Epoch 200/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5255
# Epoch 201/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5263
# Epoch 202/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5268
# Epoch 203/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5263
# Epoch 204/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5250
# Epoch 205/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5266
# Epoch 206/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5252
# Epoch 207/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5242
# Epoch 208/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5260
# Epoch 209/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5257
# Epoch 210/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5241
# Epoch 211/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5247
# Epoch 212/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5246
# Epoch 213/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5237
# Epoch 214/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5234
# Epoch 215/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5240
# Epoch 216/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5227
# Epoch 217/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5234
# Epoch 218/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5223
# Epoch 219/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5240
# Epoch 220/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5219
# Epoch 221/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5244
# Epoch 222/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5216
# Epoch 223/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5202
# Epoch 224/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5198
# Epoch 225/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5224
# Epoch 226/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5213
# Epoch 227/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5207
# Epoch 228/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5207
# Epoch 229/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5207
# Epoch 230/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5211
# Epoch 231/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5205
# Epoch 232/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5213
# Epoch 233/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5208
# Epoch 234/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5211
# Epoch 235/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5196
# Epoch 236/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5190
# Epoch 237/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5186
# Epoch 238/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5194
# Epoch 239/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5205
# Epoch 240/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5189
# Epoch 241/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5202
# Epoch 242/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5185
# Epoch 243/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5182
# Epoch 244/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5185
# Epoch 245/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5183
# Epoch 246/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5178
# Epoch 247/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5174
# Epoch 248/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5163
# Epoch 249/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5177
# Epoch 250/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5183
# Epoch 251/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5162
# Epoch 252/300
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5168
# Epoch 253/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5164
# Epoch 254/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5157
# Epoch 255/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5165
# Epoch 256/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5161
# Epoch 257/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5163
# Epoch 258/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5156
# Epoch 259/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5147
# Epoch 260/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5159
# Epoch 261/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5156
# Epoch 262/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5141
# Epoch 263/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5136
# Epoch 264/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5152
# Epoch 265/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5158
# Epoch 266/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5138
# Epoch 267/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5146
# Epoch 268/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5137
# Epoch 269/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5148
# Epoch 270/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5143
# Epoch 271/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5145
# Epoch 272/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5139
# Epoch 273/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5123
# Epoch 274/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5133
# Epoch 275/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5133
# Epoch 276/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5125
# Epoch 277/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5117
# Epoch 278/300
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5122
# Epoch 279/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5121
# Epoch 280/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5112
# Epoch 281/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5122
# Epoch 282/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5112
# Epoch 283/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5113
# Epoch 284/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5115
# Epoch 285/300
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5113
# Epoch 286/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5099
# Epoch 287/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5112
# Epoch 288/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5111
# Epoch 289/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5096
# Epoch 290/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5106
# Epoch 291/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5100
# Epoch 292/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5089
# Epoch 293/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5089
# Epoch 294/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5102
# Epoch 295/300
# 200/200 [==============================] - 1s 2ms/step - loss: 0.5093
# Epoch 296/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5110
# Epoch 297/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5103
# Epoch 298/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5091
# Epoch 299/300
# 200/200 [==============================] - 1s 2ms/step - loss: 0.5100
# Epoch 300/300
# 200/200 [==============================] - 0s 2ms/step - loss: 0.5101

# %%
# Splitting the dataset, this will not produce an exact 80/20 split but will be close and random which is fine
# Creating a 4000 long random integer array from 1 to 5
splitting = np.random.randint(1, high = 6, size = 4000)
# Assinging the training values
model2TrainingInputs = Inputs2[splitting!=5, :]
model2TrainingTargetHit = TargetHit2_binary[splitting!=5, :]
# Assigning the testing values
model2TestingInputs = Inputs2[splitting==5, :]
model2TestingTargetHit = TargetHit2_binary[splitting==5, :]
# Initialising our neural network
model2 = Sequential()

# Adding layers, these layers are two layers of 4 nodes using the ReLU function and 1 with 2 nodes using the softmax function
model2.add(Dense(units = 6, activation = 'LeakyReLU', input_dim = 6))
model2.add(Dense(units = 4, activation = 'selu'))
model2.add(Dense(units = 6, activation = 'tanh'))
model2.add(Dense(units = 4, activation = 'selu'))
model2.add(Dense(units = 6, activation = 'tanh'))
model2.add(Dense(units = 4, activation = 'LeakyReLU'))
model2.add(Dense(units = 2, activation = 'softmax'))

# Compiling the model
model2.compile(loss = 'categorical_crossentropy', optimizer = 'Adam')
# Fitting the model
model2.fit(model2TrainingInputs, model2TrainingTargetHit, epochs = 300, batch_size = 20)

# Use predict() to predict the output for the training data to get an idea of how the model is performing, this is quicker and so will be used until some models start to look decent then will move to kfold
model2testresults = model2.predict(model2TestingInputs)
# loop through to compare the test data output to what it should be and obtain the fraction of correct classifications
count = 0
for i in range(len(model2TestingTargetHit[:,0])):
  if (model2testresults[i, 0] > model2testresults[i, 1] and model2TestingTargetHit[i, 0] > model2TestingTargetHit[i, 1]) or (model2testresults[i, 0] < model2testresults[i, 1] and model2TestingTargetHit[i, 0] < model2TestingTargetHit[i, 1]):
    count = count+1
Testfractioncorrect = count / len(model2TestingTargetHit[:,0])
print(Testfractioncorrect)

model2trainresults = model2.predict(model2TrainingInputs)
count = 0
for i in range(len(model2TrainingTargetHit[:,0])):
  if (model2trainresults[i, 0] > model2trainresults[i, 1] and model2TrainingTargetHit[i, 0] > model2TrainingTargetHit[i, 1]) or (model2trainresults[i, 0] < model2trainresults[i, 1] and model2TrainingTargetHit[i, 0] < model2TrainingTargetHit[i, 1]):
    count = count+1
Trainfractioncorrect = count / len(model2TrainingTargetHit[:,0])
print(Trainfractioncorrect)

# %%
# Setting up a k fold cross validation
kf2 = KFold(n_splits = 5, shuffle = True)

# Defining empty arrays to add our fraction values to so an average can be calculated at the end
testfractions2 = 0
trainfractions2 = 0

for train_index, test_index in kf2.split(Inputs2):
  TrainingInputs = Inputs2[train_index]
  TrainingTargetHit = TargetHit2_binary[train_index]
  TestInputs = Inputs2[test_index]
  TestTargetHit = TargetHit2_binary[test_index]

  # Initialising our neural network
  model2kfold = Sequential()

  # Adding layers, these layers are two layers of 4 nodes using the ReLU function and 1 with 2 nodes using the softmax function
  model2kfold.add(Dense(units = 6, activation = 'LeakyReLU', input_dim = 6))
  model2kfold.add(Dense(units = 4, activation = 'selu'))
  model2kfold.add(Dense(units = 6, activation = 'tanh'))
  model2kfold.add(Dense(units = 4, activation = 'selu'))
  model2kfold.add(Dense(units = 6, activation = 'tanh'))
  model2kfold.add(Dense(units = 4, activation = 'LeakyReLU'))
  model2kfold.add(Dense(units = 2, activation = 'softmax'))

  # Compiling the model
  model2kfold.compile(loss = 'categorical_crossentropy', optimizer = 'Adam')

  # Use X_train, y_train to train the SVM
  model2kfold.fit(TrainingInputs, TrainingTargetHit, epochs = 300, batch_size = 20)
  # Use svm.predict() to predict the output for the test data set
  testresults = model2kfold.predict(TestInputs)
  # loop through to compare the test data output to what it should be and obtain the fraction of correct classifications
  count = 0
  for i in range(len(TestTargetHit[:,0])):
    if (testresults[i, 0] > testresults[i, 1] and TestTargetHit[i, 0] > TestTargetHit[i, 1]) or (testresults[i, 0] < testresults[i, 1] and TestTargetHit[i, 0] < TestTargetHit[i, 1]):
      count = count+1
  testfractions2 = testfractions2 + (count / len(TestTargetHit[:,0]))
  # Do the same prediction and assessment performance with the training data
  count = 0
  trainresults = model2kfold.predict(TrainingInputs)
  for i in range(len(TrainingTargetHit[:,0])):
    if (trainresults[i, 0] > trainresults[i, 1] and TrainingTargetHit[i, 0] > TrainingTargetHit[i, 1]) or (trainresults[i, 0] < trainresults[i, 1] and TrainingTargetHit[i, 0] < TrainingTargetHit[i, 1]):
      count = count+1
  trainfractions2 = trainfractions2 + (count / len(TrainingTargetHit[:,0]))

# Dividing the sum of 5 fraction values to get the average
testfraction2 = testfractions2/5
trainfraction2 = trainfractions2/5

# Printing the final accuracy values
print(testfraction2)
print(trainfraction2)

# %%
# Exporting the model
model2.save('jg619-2.h5')

# Saving the scaling parameters for temperature and strength
scArray = np.array([[ArmLength2Mean, BallWeight2Mean, BallRadius2Mean, AirTemp2Mean, SpringConst2Mean, DeviceWeight2Mean], [ArmLength2std, BallWeight2std, BallRadius2std, AirTemp2std, SpringConst2std, DeviceWeight2std]])
np.savetxt('jg619-2.txt', scArray)

# Downloading the files
from google.colab import files
files.download('jg619-2.h5')
files.download('jg619-2.txt')
